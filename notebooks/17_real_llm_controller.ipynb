# %% [markdown]
# # P2.2 Real LLM Controller
#
# This notebook runs the agent vertical against an OpenAI-compatible slow path. It reports compilation cost separately from evaluation savings.

# %%
import os
from paradigm.llm_controller import OpenAICompatibleCodingDeliberator
from paradigm.p22 import run_p22_live_benchmark

# %% [markdown]
# Required environment variables: `PARADIGM_LLM_BASE_URL` and `PARADIGM_LLM_MODEL`. Optional price variables are supported for cost estimates.

# %%
controller = OpenAICompatibleCodingDeliberator.from_env()
result = run_p22_live_benchmark(controller, quick=True)
result['evaluation']
