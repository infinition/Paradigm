# %% [markdown]
# # Paradigm Structured
#
# Research bridge to [ga-vs-scalarization](https://github.com/infinition/ga-vs-scalarization) and [arXiv:2607.06634](https://arxiv.org/abs/2607.06634).
#
# The objective is not to use geometric algebra everywhere. The controlled result to preserve is conditional: simple scalarization is sufficient on the tested single-stage equivariant laws, while native geometric composition becomes useful on the tested nested rotation tasks, especially in low data.

# %% [markdown]
# ## First Paradigm experiment
#
# Use two matched reflex tasks:
#
# 1. `rotation`: one SO(3) operation
# 2. `compose_rotation`: two nested SO(3) operations
#
# Compare:
#
# - MLP
# - scalarization
# - geometric algebra reflex
#
# Record parameter count, train time, IID NMSE, directional OOD NMSE, and sample efficiency. Only then add an architecture selector.

# %%
# Placeholder for a later direct import or copied minimal benchmark interface.
# Paradigm Core deliberately does not depend on ga-vs-scalarization.
TASKS = ["rotation", "compose_rotation"]
MODELS = ["mlp", "scalarization", "geometric"]
print({"tasks": TASKS, "models": MODELS})
