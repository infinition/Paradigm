# %% [markdown]
# # P2.0 Paradigm Agent
#
# This notebook reproduces the first concrete agent vertical. Paradigm compiles repeated controller decisions, not code generation. Unknown states fall back to the deliberative controller.

# %%
from paradigm.p20 import run_p20_benchmark
result = run_p20_benchmark(quick=True)
result["hybrid"], result["ood_only"]

# %% [markdown]
# ## What is measured
#
# - task success
# - controller decisions handled by the reflex
# - controller decisions handled by deliberation
# - OOD deferral
# - invalid reflex actions blocked before tools
#
# The reference deliberator is deterministic and local. This notebook does not claim LLM token or cost savings.

# %%
result["deliberative_call_reduction"], result["known_only"]["fast_path_coverage"]
