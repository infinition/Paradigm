# %% [markdown]
# # Core P1.4: guarded family evolution
# Inspect the recorded split, ambiguity, sequential growth, and non-permissivity controls.

# %%
import json
from pathlib import Path
path = Path('../results/core_p14/core_p14_family_evolution.json')
result = json.loads(path.read_text())
result['observed']

# %%
result['split']['decision'], result['split']['bridge_route']

# %%
result['long_run']['capture_history']

# %%
result['unsafe_controls']
