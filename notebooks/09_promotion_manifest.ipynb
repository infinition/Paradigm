# %% [markdown]
# # Paradigm Core P0.4: promotion manifest
#
# This notebook reproduces the multi-signal promotion benchmark. A candidate is promoted only when every declared check passes.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from paradigm.p04 import run_promotion_manifest_benchmark
from paradigm.reflex_space_scenarios import make_reflex_pool_scenario

# %%
scenario = make_reflex_pool_scenario(seed=1337)
result = run_promotion_manifest_benchmark(scenario, seed=1337)
result["observed_decisions"]

# %% [markdown]
# ## Clean and poisoned candidates

# %%
{name: result["cases"][name]["manifest"] for name in ["clean", "poisoned"]}

# %% [markdown]
# ## Pool-relative rejection
#
# The same valid weak-pool candidate is evaluated before and after the trusted pool is expanded.

# %%
{name: result["cases"][name]["manifest"] for name in ["weak_pool_before_expansion", "weak_pool_after_expansion"]}

# %% [markdown]
# ## Parameter-aligned adaptive candidate
#
# This candidate is generated inside the learned parameter subspace. Parameter membership passes, but the manifest still has independent behavior and semantic checks.

# %%
result["cases"]["parameter_aligned"]

# %% [markdown]
# ## Principle
#
# Paradigm keeps checks separate rather than collapsing them into one opaque score. Trust geometry is evidence, not certification.
