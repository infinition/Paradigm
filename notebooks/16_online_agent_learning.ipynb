# %% [markdown]
# # P2.1 Online Agent Learning
#
# Outcome-filtered supervised reflex compilation during agent use.

# %%
from paradigm.p21 import run_p21_benchmark
result = run_p21_benchmark(quick=True)
result["online"]

# %%
result["novel_family"]

# %%
result["promotions"]

# %%
result["bounded_neural_candidate"]
